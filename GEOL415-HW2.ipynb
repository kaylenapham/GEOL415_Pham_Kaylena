# %%
import pandas as pd
import matplotlib.pyplot as plt	
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

# %%
git remote add origin https://github.com/kaylenapham/GEOL415_Pham_Kaylena.git
git branch -M main
git push -u origin main
# Out:
#   Cell In[7], line 1
#     git remote add origin https://github.com/kaylenapham/GEOL415_Pham_Kaylena.git
#         ^
# SyntaxError: invalid syntax
